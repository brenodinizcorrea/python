# %% [markdown]
# # Exercise 1 — NameError
#
# Create a variable called `city` and print it.
#
# Then try to print a variable that has not been defined.
#
# Fix the code after identifying the error.

# %%
city = 'Fortaleza'

print(city)

print(age)
# Out:
# Fortaleza
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 city = 'Fortaleza'
#       3 print(city)
# ----> 5 print(age)
#
# NameError: name 'age' is not defined

# %% [markdown]
# # Exercise 2 — TypeError
#
# Create a number and a string.
#
# Try to combine them using an operation that produces a `TypeError`.
#
# Then modify the code so the operation becomes valid.

# %%
number = 20

example_string = 'string'

print(number + example_string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 number = 20
#       3 example_string = 'string'
# ----> 5 print(number + example_string)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
number = 20

number_2 = 30

print(number + number_2)
# Out:
# 50

# %% [markdown]
# # Exercise 3 — ValueError
#
# Create a list containing strings that represent different values.
#
# Use `int()` to convert them to integers.
#
# Include at least one value that cannot be converted.
#
# After observing the error, modify the code so all conversions are valid.

# %%
numbers_in_strings_list = ['1', '2', '3', '4']

numbers_in_strings_list_converted = [int(number) for number in numbers_in_strings_list]

print(numbers_in_strings_list_converted)

numbers_in_strings_list = ['1', '2', '3', '4', 'abc']

numbers_in_strings_list_converted = [int(number) for number in numbers_in_strings_list]

print(numbers_in_strings_list_converted)
# Out:
# [1, 2, 3, 4]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 9
#       5 print(numbers_in_strings_list_converted)
#       7 numbers_in_strings_list = ['1', '2', '3', '4', 'abc']
# ----> 9 numbers_in_strings_list_converted = [int(number) for number in numbers_in_strings_list]
#      11 print(numbers_in_strings_list_converted)
#
# Cell In[6], line 9, in <listcomp>(.0)
#       5 print(numbers_in_strings_list_converted)
#       7 numbers_in_strings_list = ['1', '2', '3', '4', 'abc']
# ----> 9 numbers_in_strings_list_converted = [int(number) for number in numbers_in_strings_list]
#      11 print(numbers_in_strings_list_converted)
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# # Exercise 4 — IndexError
#
# Create a list with five elements.
#
# Write code that accesses:
#
# - one valid index;
# - the last element;
# - an index that does not exist.
#
# After observing the error, correct the invalid access.

# %%
example_list = [10, 20, 30, 40, 50]

print(example_list[2])
print(example_list[-1])
print(example_list[5])
# Out:
# 30
# 50
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 5
#       3 print(example_list[2])
#       4 print(example_list[-1])
# ----> 5 print(example_list[5])
#
# IndexError: list index out of range

# %% [markdown]
# # Exercise 5 — KeyError
#
# Create a dictionary representing a person, with at least three keys.
#
# Write code that accesses an existing key and a key that does not exist.
#
# After observing the error, correct the invalid access.
#
# Finally, access the three valid keys.

# %%
example_dict ={
    'name': 'Ana',
    'age': 23,
    'city': 'Fortaleza'
}

print(example_dict['name'])
print(example_dict['country'])
# Out:
# Ana
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 8
#       1 example_dict ={
#       2     'name': 'Ana',
#       3     'age': 23,
#       4     'city': 'Fortaleza'
#       5 }
#       7 print(example_dict['name'])
# ----> 8 print(example_dict['country'])
#
# KeyError: 'country'
